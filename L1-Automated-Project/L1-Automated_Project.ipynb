# %% [markdown]
# # L1: Automated Project: Planning, Estimation, and Allocation

# %% [markdown]
# <p style="background-color:#fff6e4; padding:15px; border-width:3px; border-color:#f5ecda; border-style:solid; border-radius:6px"> ⏳ <b>Note <code>(Kernel Starting)</code>:</b> This notebook takes about 30 seconds to be ready to use. You may start and watch the video while you wait.</p>

# %% [markdown]
# ## Initial Imports

# %%
# Warning control
import warnings
warnings.filterwarnings('ignore')

# Load environment variables
from helper import load_env
load_env()

import os
import yaml
from crewai import Agent, Task, Crew

# %% [markdown]
# <p style="background-color:#fff6ff; padding:15px; border-width:3px; border-color:#efe6ef; border-style:solid; border-radius:6px"> 💻 &nbsp; <b>Access <code>requirements.txt</code> and <code>helper.py</code> files:</b> 1) click on the <em>"File"</em> option on the top menu of the notebook and then 2) click on <em>"Open"</em>. For more help, please see the <em>"Appendix - Tips and Help"</em> Lesson.</p>

# %% [markdown]
# ## Set OpenAI Model

# %%
os.environ['OPENAI_MODEL_NAME'] = 'gpt-4o-mini'

# %% [markdown]
# ## Loading Tasks and Agents YAML files

# %%
# Define file paths for YAML configurations
files = {
    'agents': 'config/agents.yaml',
    'tasks': 'config/tasks.yaml'
}

# Load configurations from YAML files
configs = {}
for config_type, file_path in files.items():
    with open(file_path, 'r') as file:
        configs[config_type] = yaml.safe_load(file)

# Assign loaded configurations to specific variables
agents_config = configs['agents']
tasks_config = configs['tasks']

# %% [markdown]
# ## Create Pydantic Models for Structured Output

# %%
from typing import List
from pydantic import BaseModel, Field

class TaskEstimate(BaseModel):
    task_name: str = Field(..., description="Name of the task")
    estimated_time_hours: float = Field(..., description="Estimated time to complete the task in hours")
    required_resources: List[str] = Field(..., description="List of resources required to complete the task")

class Milestone(BaseModel):
    milestone_name: str = Field(..., description="Name of the milestone")
    tasks: List[str] = Field(..., description="List of task IDs associated with this milestone")

class ProjectPlan(BaseModel):
    tasks: List[TaskEstimate] = Field(..., description="List of tasks with their estimates")
    milestones: List[Milestone] = Field(..., description="List of project milestones")

# %% [markdown]
# ## Create Crew, Agents and Tasks

# %%
# Creating Agents
project_planning_agent = Agent(
  config=agents_config['project_planning_agent']
)

estimation_agent = Agent(
  config=agents_config['estimation_agent']
)

resource_allocation_agent = Agent(
  config=agents_config['resource_allocation_agent']
)

# Creating Tasks
task_breakdown = Task(
  config=tasks_config['task_breakdown'],
  agent=project_planning_agent
)

time_resource_estimation = Task(
  config=tasks_config['time_resource_estimation'],
  agent=estimation_agent
)

resource_allocation = Task(
  config=tasks_config['resource_allocation'],
  agent=resource_allocation_agent,
  output_pydantic=ProjectPlan # This is the structured output we want
)

# Creating Crew
crew = Crew(
  agents=[
    project_planning_agent,
    estimation_agent,
    resource_allocation_agent
  ],
  tasks=[
    task_breakdown,
    time_resource_estimation,
    resource_allocation
  ],
  verbose=True
)

# %% [markdown]
# ## Crew's Inputs

# %%
from IPython.display import display, Markdown

project = 'Website'
industry = 'Technology'
project_objectives = 'Create a website for a small business'
team_members = """
- John Doe (Project Manager)
- Jane Doe (Software Engineer)
- Bob Smith (Designer)
- Alice Johnson (QA Engineer)
- Tom Brown (QA Engineer)
"""
project_requirements = """
- Create a responsive design that works well on desktop and mobile devices
- Implement a modern, visually appealing user interface with a clean look
- Develop a user-friendly navigation system with intuitive menu structure
- Include an "About Us" page highlighting the company's history and values
- Design a "Services" page showcasing the business's offerings with descriptions
- Create a "Contact Us" page with a form and integrated map for communication
- Implement a blog section for sharing industry news and company updates
- Ensure fast loading times and optimize for search engines (SEO)
- Integrate social media links and sharing capabilities
- Include a testimonials section to showcase customer feedback and build trust
"""

# Format the dictionary as Markdown for a better display in Jupyter Lab
formatted_output = f"""
**Project Type:** {project}

**Project Objectives:** {project_objectives}

**Industry:** {industry}

**Team Members:**
{team_members}
**Project Requirements:**
{project_requirements}
"""
# Display the formatted output as Markdown
display(Markdown(formatted_output))
# Out:
# **Project Type:** Website
#
# **Project Objectives:** Create a website for a small business
#
# **Industry:** Technology
#
# **Team Members:**
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
# **Project Requirements:**
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust

# %% [markdown]
# ## Kicking off the crew

# %%
# The given Python dictionary
inputs = {
  'project_type': project,
  'project_objectives': project_objectives,
  'industry': industry,
  'team_members': team_members,
  'project_requirements': project_requirements
}

# Run the crew
result = crew.kickoff(
  inputs=inputs
)
# Out:
# # Agent: The Ultimate Project Planner
# ## Task: Carefully analyze the project_requirements for the Website project and break them down into individual tasks. Define each task's scope in detail, set achievable timelines, and ensure that all dependencies are accounted for:
#
# - Create a responsive design that works well on desktop and mobile devices
# - Implement a modern, visually appealing user interface with a clean look
# - Develop a user-friendly navigation system with intuitive menu structure
# - Include an "About Us" page highlighting the company's history and values
# - Design a "Services" page showcasing the business's offerings with descriptions
# - Create a "Contact Us" page with a form and integrated map for communication
# - Implement a blog section for sharing industry news and company updates
# - Ensure fast loading times and optimize for search engines (SEO)
# - Integrate social media links and sharing capabilities
# - Include a testimonials section to showcase customer feedback and build trust
#
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
#
#
#
#
# # Agent: The Ultimate Project Planner
# ## Final Answer:
# ### Comprehensive Task Breakdown for Website Project
#
# #### Overview:
# The project involves creating a fully functional and visually appealing website for a small business that is responsive, user-friendly, and optimized for speed and search engines. The project will be broken down into the following tasks, each with defined scope, timelines, dependencies, and deliverables.
#
# ---
#
# ### Task Breakdown
#
# 1. **Create Responsive Design**
#    - **Scope**: Design layout for desktop and mobile; ensure responsiveness across various screen sizes.
#    - **Deliverables**: Wireframes and mockups for desktop and mobile.
#    - **Timeline**: Week 1 - Week 2
#    - **Dependencies**: None.
#
# 2. **Implement Modern User Interface**
#    - **Scope**: Develop a visually appealing UI using the latest design trends; focus on a clean aesthetic.
#    - **Deliverables**: Completed CSS styles and HTML structure for website pages.
#    - **Timeline**: Week 3 - Week 4
#    - **Dependencies**: Completion of the responsive design.
#
# 3. **Develop User-Friendly Navigation System**
#    - **Scope**: Create intuitive menus and navigation paths to enhance user experience.
#    - **Deliverables**: Functional navigation bar; tested navigation paths.
#    - **Timeline**: Week 4
#    - **Dependencies**: Completion of the UI implementation.
#
# 4. **Create "About Us" Page**
#    - **Scope**: Write and design content highlighting company history and values.
#    - **Deliverables**: Completed design and copy for "About Us" page.
#    - **Timeline**: Week 5
#    - **Dependencies**: Navigation system development.
#
# 5. **Design "Services" Page**
#    - **Scope**: Showcase business offerings with detailed descriptions and visuals.
#    - **Deliverables**: Completed design and content for "Services" page.
#    - **Timeline**: Week 5 - Week 6
#    - **Dependencies**: Completion of "About Us" page.
#
# 6. **Create "Contact Us" Page**
#    - **Scope**: Include a contact form and integrate a map for location.
#    - **Deliverables**: Contact form functionality; integrated Google map.
#    - **Timeline**: Week 6
#    - **Dependencies**: Completion of "Services" page.
#
# 7. **Implement Blog Section**
#    - **Scope**: Develop a section for posting articles, updates, and news.
#    - **Deliverables**: Blog page structure and content management system integration.
#    - **Timeline**: Week 7
#    - **Dependencies**: Completion of "Contact Us" page.
#
# 8. **Ensure Fast Loading Times & SEO Optimization**
#    - **Scope**: Optimize images, scripts, and overall site performance; implement SEO best practices.
#    - **Deliverables**: Performance benchmarks; SEO optimized pages.
#    - **Timeline**: Week 8
#    - **Dependencies**: Website structure completion (UI & content).
#
# 9. **Integrate Social Media Links & Sharing Capabilities**
#    - **Scope**: Add social media links and enable sharing functionalities on posts.
#    - **Deliverables**: Functional social media integrations.
#    - **Timeline**: Week 8
#    - **Dependencies**: Completion of blog section.
#
# 10. **Include Testimonials Section**
#     - **Scope**: Showcase customer feedback to build trust and credibility.
#     - **Deliverables**: Completed Testimonials section design and functionality.
#     - **Timeline**: Week 9
#     - **Dependencies**: Completion of previous tasks.
#
# 11. **Quality Assurance Testing**
#     - **Scope**: Conduct thorough testing of the website for bugs, usability, and performance.
#     - **Deliverables**: QA report; necessary adjustments made.
#     - **Timeline**: Week 10
#     - **Dependencies**: Completion of all previous tasks.
#
# 12. **Launch Website**
#     - **Scope**: Final checks and prepare for launch; execute marketing plan.
#     - **Deliverables**: Live website; marketing materials.
#     - **Timeline**: Week 11
#     - **Dependencies**: Successful completion of QA testing.
#
# ---
#
# ### Team Assignments
#
# - John Doe (Project Manager): Oversees the project timeline, task delegation, and communication.
# - Jane Doe (Software Engineer): Implements website structure, functionality, and testing.
# - Bob Smith (Designer): Focus on UI/UX design and ensuring visual elements are aligned with the concept.
# - Alice Johnson (QA Engineer): Conducts testing and ensures quality standards are met.
# - Tom Brown (QA Engineer): Supports QA efforts and handles user experience testing.
#
# ---
#
# ### Gantt Chart Visualization
#
# ```plaintext
# | Task                                   | Week 1 | Week 2 | Week 3 | Week 4 | Week 5 | Week 6 | Week 7 | Week 8 | Week 9 | Week 10 | Week 11 |
# |----------------------------------------|--------|--------|--------|--------|--------|--------|--------|--------|--------|---------|---------|
# | Create Responsive Design               |   ██████  |        |        |        |        |        |        |        |        |         |         |
# | Implement Modern User Interface        |        |        |   ██████  |   ██████  |        |        |        |        |        |         |         |
# | Develop User-Friendly Navigation System |        |        |        |   ██████  |        |        |        |        |        |         |         |
# | Create "About Us" Page                |        |        |        |        |   ██████  |        |        |        |        |         |         |
# | Design "Services" Page                |        |        |        |        |   ██████  |   ██████  |        |        |        |         |         |
# | Create "Contact Us" Page              |        |        |        |        |        |   ██████  |        |        |        |         |         |
# | Implement Blog Section                 |        |        |        |        |        |        |   ██████  |        |        |         |         |
# | Fast Loading Times & SEO Optimization   |        |        |        |        |        |        |        |   ██████  |        |         |         |
# | Integrate Social Media Links           |        |        |        |        |        |        |        |   ██████  |        |         |         |
# | Include Testimonials Section            |        |        |        |        |        |        |        |        |   ██████  |         |         |
# | Quality Assurance Testing               |        |        |        |        |        |        |        |        |        |   ██████  |         |
# | Launch Website                         |        |        |        |        |        |        |        |        |        |         |   ██████  |
# ```
#
# ### Conclusion
# This breakdown ensures that each task is meticulously planned, with clear dependencies and timelines, so the project can deliver a successful website for the small business while keeping all team members on track and informed throughout the process.
#
#
# # Agent: Expert Estimation Analyst
# ## Task: Thoroughly evaluate each task in the Website project to estimate the time, resources, and effort required. Use historical data, task complexity, and available resources to provide a realistic estimation for each task.
#
#
#
# # Agent: Expert Estimation Analyst
# ## Final Answer:
# ### Detailed Estimation Report for Website Project
#
# #### 1. Create Responsive Design
# - **Time**: 2 weeks
# - **Resources**: 1 Designer (Bob Smith)
# - **Effort**: 80 hours (40 hours/week)
# - **Risks**: Delays in approval of wireframes could affect subsequent tasks.
#
# #### 2. Implement Modern User Interface
# - **Time**: 2 weeks
# - **Resources**: 1 Software Engineer (Jane Doe)
# - **Effort**: 80 hours (40 hours/week)
# - **Risks**: Potential design revisions may prolong the timeline.
#
# #### 3. Develop User-Friendly Navigation System
# - **Time**: 1 week
# - **Resources**: 1 Software Engineer (Jane Doe)
# - **Effort**: 40 hours
# - **Risks**: Complexity in integration with existing UI may require additional time.
#
# #### 4. Create "About Us" Page
# - **Time**: 1 week
# - **Resources**: 1 Designer (Bob Smith) and 1 Content Writer
# - **Effort**: 40 hours (20 hours design + 20 hours writing)
# - **Risks**: Content approval delays may push back deadlines.
#
# #### 5. Design "Services" Page
# - **Time**: 2 weeks
# - **Resources**: 1 Designer (Bob Smith) and 1 Content Writer
# - **Effort**: 80 hours (40 hours design + 40 hours writing)
# - **Risks**: Changes in services offered by the business may lead to design revisions.
#
# #### 6. Create "Contact Us" Page
# - **Time**: 1 week
# - **Resources**: 1 Software Engineer (Jane Doe)
# - **Effort**: 40 hours
# - **Risks**: Technical issues with map integration could lead to delays.
#
# #### 7. Implement Blog Section
# - **Time**: 1 week
# - **Resources**: 1 Software Engineer (Jane Doe) and 1 Content Writer
# - **Effort**: 40 hours (20 hours development + 20 hours writing)
# - **Risks**: Blog CMS integration could encounter unexpected challenges.
#
# #### 8. Ensure Fast Loading Times & SEO Optimization
# - **Time**: 1 week
# - **Resources**: 1 Software Engineer (Jane Doe)
# - **Effort**: 40 hours
# - **Risks**: Inadequate website performance could require additional optimization efforts.
#
# #### 9. Integrate Social Media Links & Sharing Capabilities
# - **Time**: 1 week
# - **Resources**: 1 Software Engineer (Jane Doe)
# - **Effort**: 40 hours
# - **Risks**: Changes in social media API requirements may necessitate rework.
#
# #### 10. Include Testimonials Section
# - **Time**: 1 week
# - **Resources**: 1 Designer (Bob Smith)
# - **Effort**: 40 hours
# - **Risks**: Collecting testimonials from users could take longer than expected.
#
# #### 11. Quality Assurance Testing
# - **Time**: 1 week
# - **Resources**: 2 QA Engineers (Alice Johnson and Tom Brown)
# - **Effort**: 80 hours (40 hours each)
# - **Risks**: Identified bugs may require revisions that could extend the testing phase.
#
# #### 12. Launch Website
# - **Time**: 1 week
# - **Resources**: 1 Project Manager (John Doe) and Marketing Team
# - **Effort**: 40 hours
# - **Risks**: Last-minute issues or marketing delays may postpone the launch.
#
# ### Summary of Risks/Uncertainties
# - Approval delays in design and content could impact multiple tasks.
# - Technical challenges can arise during implementation stages affecting timelines.
# - Changes to project scope, such as additional features or design requests, can cause budget overruns and extend deadlines.
# - Dependencies must be closely monitored to keep the project on track.
#
# The above estimations include individual task timelines, resources, and estimated effort, offering a comprehensive view of the project requirements. Maintaining open channels of communication within the team and with stakeholders will be critical to overcoming potential risks.
#
#
# # Agent: Resource Allocation Strategist
# ## Task: Strategically allocate tasks for the Website project to team members based on their skills, availability, and current workload. Ensure that each task is assigned to the most suitable team member and that the workload is evenly distributed.
#
# Team members:
#
# - John Doe (Project Manager)
# - Jane Doe (Software Engineer)
# - Bob Smith (Designer)
# - Alice Johnson (QA Engineer)
# - Tom Brown (QA Engineer)
# # Agent: Resource Allocation Strategist
# ## Final Answer:
# ### Resource Allocation Chart for the Website Project
#
# | Task                                             | Team Members               | Start Date | End Date   | Total Effort (Hours) |
# |--------------------------------------------------|----------------------------|------------|------------|-----------------------|
# | 1. Create Responsive Design                       | Bob Smith                  | Week 1    | Week 2    | 80                    |
# | 2. Implement Modern User Interface                | Jane Doe                   | Week 3    | Week 4    | 80                    |
# | 3. Develop User-Friendly Navigation System        | Jane Doe                   | Week 5    | Week 5    | 40                    |
# | 4. Create "About Us" Page                        | Bob Smith, Content Writer  | Week 6    | Week 6    | 40                    |
# | 5. Design "Services" Page                        | Bob Smith, Content Writer  | Week 7    | Week 8    | 80                    |
# | 6. Create "Contact Us" Page                      | Jane Doe                   | Week 9    | Week 9    | 40                    |
# | 7. Implement Blog Section                         | Jane Doe, Content Writer   | Week 10   | Week 10   | 40                    |
# | 8. Ensure Fast Loading Times & SEO Optimization   | Jane Doe                   | Week 11   | Week 11   | 40                    |
# | 9. Integrate Social Media Links & Sharing Capabilities | Jane Doe               | Week 12   | Week 12   | 40                    |
# | 10. Include Testimonials Section                  | Bob Smith                  | Week 13   | Week 13   | 40                    |
# | 11. Quality Assurance Testing                     | Alice Johnson, Tom Brown   | Week 14   | Week 14   | 80                    |
# | 12. Launch Website                                | John Doe and Marketing Team| Week 15   | Week 15   | 40                    |
#
# ### Summary of Allocation Rationale:
#
# 1. **Create Responsive Design**: Assigned to *Bob Smith (Designer)* as he has the specific skills required to create a visually appealing and responsive design. The task duration is set for 2 weeks to accommodate potential delays in approval of wireframes.
#
# 2. **Implement Modern User Interface**: Given to *Jane Doe (Software Engineer)* who has expertise in implementing user interfaces. Task spans 2 weeks to account for possible design revisions.
#
# 3. **Develop User-Friendly Navigation System**: *Jane Doe* continues on this task as the appropriate resource due to the anticipated complexity and requirement for cohesive integration with the existing UI. It's allocated 1 week.
#
# 4. **Create "About Us" Page**: This task requires both design and content writing, so it’s assigned to *Bob Smith* along with a Content Writer. The task is set for 1 week given the necessity of content approvals which may cause delays.
#
# 5. **Design "Services" Page**: Assigning *Bob Smith* and a Content Writer again due to the combined effort required for design and writing. This task spans 2 weeks because of the potential for design revisions based on changing services.
#
# 6. **Create "Contact Us" Page**: Assigned to *Jane Doe* as it requires coding the UI elements; scheduled for 1 week, allowing reasonable time for possible technical difficulties.
#
# 7. **Implement Blog Section**: Allocation includes *Jane Doe* and a Content Writer as development and content creation are required. Given the possible challenges, this task is allotted for 1 week.
#
# 8. **Ensure Fast Loading Times & SEO Optimization**: Given to *Jane Doe*, since site performance optimization requires technical know-how; this task is set for 1 week.
#
# 9. **Integrate Social Media Links & Sharing Capabilities**: Again assigned to *Jane Doe* who is the most suitable resource for this technical integration; scheduled for 1 week.
#
# 10. **Include Testimonials Section**: Tasked to *Bob Smith* as it falls under design work; allocated for 1 week to handle potential delays in gathering testimonials.
#
# 11. **Quality Assurance Testing**: **Alice Johnson and Tom Brown (QA Engineers)** are assigned to ensure thorough testing of the entire website, spanning 1 week. Given the potential for revisions, sufficient overlap in their schedules further supports quality assurance.
#
# 12. **Launch Website**: Finally, *John Doe (Project Manager)* takes forefront alongside the Marketing Team for the website launch in 1 week, accommodating any last-minute adjustments from various teams.
#
# This detailed allocation attempts to distribute tasks based on individual strengths, align workloads appropriately, and facilitate communication amongst team members to enhance project success while monitoring risks effectively throughout the process.

# %% [markdown]
# ## Usage Metrics and Costs

# %% [markdown]
# Let’s see how much it would cost each time if this crew runs at scale.

# %%
import pandas as pd

costs = 0.150 * (crew.usage_metrics.prompt_tokens + crew.usage_metrics.completion_tokens) / 1_000_000
print(f"Total costs: ${costs:.4f}")

# Convert UsageMetrics instance to a DataFrame
df_usage_metrics = pd.DataFrame([crew.usage_metrics.dict()])
df_usage_metrics
# Out:
# Total costs: $0.0028
#    total_tokens  prompt_tokens  completion_tokens  successful_requests
# 0         18816          11438               7378                    9

# %% [markdown]
# ## Result

# %%
result.pydantic.dict()
# Out:
# {'tasks': [{'task_name': 'Create Responsive Design',
#    'estimated_time_hours': 80.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': 'Implement Modern User Interface',
#    'estimated_time_hours': 80.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Develop User-Friendly Navigation System',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Create "About Us" Page',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Bob Smith', 'Content Writer']},
#   {'task_name': 'Design "Services" Page',
#    'estimated_time_hours': 80.0,
#    'required_resources': ['Bob Smith', 'Content Writer']},
#   {'task_name': 'Create "Contact Us" Page',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Implement Blog Section',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe', 'Content Writer']},
#   {'task_name': 'Ensure Fast Loading Times & SEO Optimization',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Integrate Social Media Links & Sharing Capabilities',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Jane Doe']},
#   {'task_name': 'Include Testimonials Section',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['Bob Smith']},
#   {'task_name': 'Quality Assurance Testing',
#    'estimated_time_hours': 80.0,
#    'required_resources': ['Alice Johnson', 'Tom Brown']},
#   {'task_name': 'Launch Website',
#    'estimated_time_hours': 40.0,
#    'required_resources': ['John Doe', 'Marketing Team']}],
#  'milestones': [{'milestone_name': 'Design Phase Completed',
#    'tasks': ['Create Responsive Design',
#     'Implement Modern User Interface',
#     'Create "About Us" Page',
#     'Design "Services" Page']},
#   {'milestone_name': 'Development Phase Completed',
#    'tasks': ['Develop User-Friendly Navigation System',
#     'Create "Contact Us" Page',
#     'Implement Blog Section',
#     'Ensure Fast Loading Times & SEO Optimization',
#     'Integrate Social Media Links & Sharing Capabilities',
#     'Include Testimonials Section']},
#   {'milestone_name': 'Testing Phase Completed',
#    'tasks': ['Quality Assurance Testing']},
#   {'milestone_name': 'Launch Phase Completed', 'tasks': ['Launch Website']}]}

# %% [markdown]
# ## Inspect further

# %%
tasks = result.pydantic.dict()['tasks']
df_tasks = pd.DataFrame(tasks)

# Display the DataFrame as an HTML table
df_tasks.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_87cf8 th {
#   font-size: 120%;
# }
# #T_87cf8  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_87cf8" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_87cf8_level0_col0" class="col_heading level0 col0" >task_name</th>
#       <th id="T_87cf8_level0_col1" class="col_heading level0 col1" >estimated_time_hours</th>
#       <th id="T_87cf8_level0_col2" class="col_heading level0 col2" >required_resources</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_87cf8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_87cf8_row0_col0" class="data row0 col0" >Create Responsive Design</td>
#       <td id="T_87cf8_row0_col1" class="data row0 col1" >80.000000</td>
#       <td id="T_87cf8_row0_col2" class="data row0 col2" >['Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_87cf8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_87cf8_row1_col0" class="data row1 col0" >Implement Modern User Interface</td>
#       <td id="T_87cf8_row1_col1" class="data row1 col1" >80.000000</td>
#       <td id="T_87cf8_row1_col2" class="data row1 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_87cf8_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_87cf8_row2_col0" class="data row2 col0" >Develop User-Friendly Navigation System</td>
#       <td id="T_87cf8_row2_col1" class="data row2 col1" >40.000000</td>
#       <td id="T_87cf8_row2_col2" class="data row2 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_87cf8_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_87cf8_row3_col0" class="data row3 col0" >Create "About Us" Page</td>
#       <td id="T_87cf8_row3_col1" class="data row3 col1" >40.000000</td>
#       <td id="T_87cf8_row3_col2" class="data row3 col2" >['Bob Smith', 'Content Writer']</td>
#     </tr>
#     <tr>
#       <th id="T_87cf8_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_87cf8_row4_col0" class="data row4 col0" >Design "Services" Page</td>
#       <td id="T_87cf8_row4_col1" class="data row4 col1" >80.000000</td>
#       <td id="T_87cf8_row4_col2" class="data row4 col2" >['Bob Smith', 'Content Writer']</td>
#     </tr>
#     <tr>
#       <th id="T_87cf8_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_87cf8_row5_col0" class="data row5 col0" >Create "Contact Us" Page</td>
#       <td id="T_87cf8_row5_col1" class="data row5 col1" >40.000000</td>
#       <td id="T_87cf8_row5_col2" class="data row5 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_87cf8_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_87cf8_row6_col0" class="data row6 col0" >Implement Blog Section</td>
#       <td id="T_87cf8_row6_col1" class="data row6 col1" >40.000000</td>
#       <td id="T_87cf8_row6_col2" class="data row6 col2" >['Jane Doe', 'Content Writer']</td>
#     </tr>
#     <tr>
#       <th id="T_87cf8_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_87cf8_row7_col0" class="data row7 col0" >Ensure Fast Loading Times & SEO Optimization</td>
#       <td id="T_87cf8_row7_col1" class="data row7 col1" >40.000000</td>
#       <td id="T_87cf8_row7_col2" class="data row7 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_87cf8_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_87cf8_row8_col0" class="data row8 col0" >Integrate Social Media Links & Sharing Capabilities</td>
#       <td id="T_87cf8_row8_col1" class="data row8 col1" >40.000000</td>
#       <td id="T_87cf8_row8_col2" class="data row8 col2" >['Jane Doe']</td>
#     </tr>
#     <tr>
#       <th id="T_87cf8_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_87cf8_row9_col0" class="data row9 col0" >Include Testimonials Section</td>
#       <td id="T_87cf8_row9_col1" class="data row9 col1" >40.000000</td>
#       <td id="T_87cf8_row9_col2" class="data row9 col2" >['Bob Smith']</td>
#     </tr>
#     <tr>
#       <th id="T_87cf8_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_87cf8_row10_col0" class="data row10 col0" >Quality Assurance Testing</td>
#       <td id="T_87cf8_row10_col1" class="data row10 col1" >80.000000</td>
#       <td id="T_87cf8_row10_col2" class="data row10 col2" >['Alice Johnson', 'Tom Brown']</td>
#     </tr>
#     <tr>
#       <th id="T_87cf8_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_87cf8_row11_col0" class="data row11 col0" >Launch Website</td>
#       <td id="T_87cf8_row11_col1" class="data row11 col1" >40.000000</td>
#       <td id="T_87cf8_row11_col2" class="data row11 col2" >['John Doe', 'Marketing Team']</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Inspecting Milestones

# %%
milestones = result.pydantic.dict()['milestones']
df_milestones = pd.DataFrame(milestones)

# Display the DataFrame as an HTML table
df_milestones.style.set_table_attributes('border="1"').set_caption("Task Details").set_table_styles(
    [{'selector': 'th, td', 'props': [('font-size', '120%')]}]
)
# Out:
# <style type="text/css">
# #T_2493b th {
#   font-size: 120%;
# }
# #T_2493b  td {
#   font-size: 120%;
# }
# </style>
# <table id="T_2493b" border="1">
#   <caption>Task Details</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2493b_level0_col0" class="col_heading level0 col0" >milestone_name</th>
#       <th id="T_2493b_level0_col1" class="col_heading level0 col1" >tasks</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2493b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2493b_row0_col0" class="data row0 col0" >Design Phase Completed</td>
#       <td id="T_2493b_row0_col1" class="data row0 col1" >['Create Responsive Design', 'Implement Modern User Interface', 'Create "About Us" Page', 'Design "Services" Page']</td>
#     </tr>
#     <tr>
#       <th id="T_2493b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2493b_row1_col0" class="data row1 col0" >Development Phase Completed</td>
#       <td id="T_2493b_row1_col1" class="data row1 col1" >['Develop User-Friendly Navigation System', 'Create "Contact Us" Page', 'Implement Blog Section', 'Ensure Fast Loading Times & SEO Optimization', 'Integrate Social Media Links & Sharing Capabilities', 'Include Testimonials Section']</td>
#     </tr>
#     <tr>
#       <th id="T_2493b_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2493b_row2_col0" class="data row2 col0" >Testing Phase Completed</td>
#       <td id="T_2493b_row2_col1" class="data row2 col1" >['Quality Assurance Testing']</td>
#     </tr>
#     <tr>
#       <th id="T_2493b_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2493b_row3_col0" class="data row3 col0" >Launch Phase Completed</td>
#       <td id="T_2493b_row3_col1" class="data row3 col1" >['Launch Website']</td>
#     </tr>
#   </tbody>
# </table>
